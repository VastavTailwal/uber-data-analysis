# %% [markdown]
# # **<p style="text-align: center;"><u>Uber Data Analysis</u></p>**

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Loading and Understanding Data

# %%
df = pd.read_csv('uber_data.csv', parse_dates=['tpep_pickup_datetime', 'tpep_dropoff_datetime'])
df.sample(5)
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 57928         2  2016-03-10 12:38:15   2016-03-10 12:48:46                1
# 76478         2  2016-03-10 13:39:32   2016-03-10 13:58:51                1
# 65485         2  2016-03-01 00:06:20   2016-03-01 00:20:45                1
# 62646         2  2016-03-10 13:04:36   2016-03-10 13:14:59                1
# 95043         2  2016-03-10 14:01:37   2016-03-10 14:03:35                6
#
#        trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 57928           1.42        -73.991661        40.750340           1
# 76478           2.42        -73.986359        40.758339           1
# 65485           6.18        -73.959053        40.708889           1
# 62646           0.99        -73.983467        40.770996           1
# 95043           0.42        -73.972733        40.761776           1
#
#       store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# ...

# %%
df.shape
# Out:
# (100000, 19)

# %% [markdown]
# Our data contains `100000` samples and `19` features.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   VendorID               100000 non-null  int64
#  1   tpep_pickup_datetime   100000 non-null  datetime64[ns]
#  2   tpep_dropoff_datetime  100000 non-null  datetime64[ns]
#  3   passenger_count        100000 non-null  int64
#  4   trip_distance          100000 non-null  float64
#  5   pickup_longitude       100000 non-null  float64
#  6   pickup_latitude        100000 non-null  float64
#  7   RatecodeID             100000 non-null  int64
#  8   store_and_fwd_flag     100000 non-null  object
#  9   dropoff_longitude      100000 non-null  float64
#  10  dropoff_latitude       100000 non-null  float64
#  11  payment_type           100000 non-null  int64
#  12  fare_amount            100000 non-null  float64
#  13  extra                  100000 non-null  float64
# ...

# %%
df.describe()
# Out:
#            VendorID  passenger_count  trip_distance  pickup_longitude  \
# count  100000.00000    100000.000000  100000.000000     100000.000000
# mean        1.88327         1.929170       3.034270        -73.288983
# std         0.32110         1.589408       3.846951          7.089652
# min         1.00000         0.000000       0.000000       -121.933327
# 25%         2.00000         1.000000       0.990000        -73.990959
# 50%         2.00000         1.000000       1.670000        -73.980202
# 75%         2.00000         2.000000       3.200000        -73.964203
# max         2.00000         6.000000     184.400000          0.000000
#
#        pickup_latitude     RatecodeID  dropoff_longitude  dropoff_latitude  \
# count    100000.000000  100000.000000      100000.000000     100000.000000
# mean         40.375220       1.040120         -73.312418         40.388064
# std           3.901413       0.284238           6.964171          3.833974
# ...

# %%
df.isna().sum()
# Out:
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# pickup_longitude         0
# pickup_latitude          0
# RatecodeID               0
# store_and_fwd_flag       0
# dropoff_longitude        0
# dropoff_latitude         0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Data has no duplicates or null values.

# %% [markdown]
# ## To be continued...
